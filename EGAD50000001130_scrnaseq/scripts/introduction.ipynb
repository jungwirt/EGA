# %% [markdown]
# ### Non-covid samples vs control from Maatz, H., Lindberg, E.L., Adami, E. et al. The cellular and molecular cardiac tissue responses in human inflammatory cardiomyopathies after SARS-CoV-2 infection and COVID-19 vaccination. *Nat Cardiovasc Res* **4**, 330–345 (2025).
# ***
# ###### Author: Maks Nęcki
# ***

# %%
import numpy as np
import pandas as pd
import anndata as ad
from scipy.sparse import csr_matrix
print(ad.__version__)
# Out:
# 0.12.2

# %%
BS_H15_AP0_premrna = ad.read_hdf('../raw_data/down')
